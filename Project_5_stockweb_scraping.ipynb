# %%
import yfinance as yf
import pandas as pd
import datetime as dt
from datetime import date, timedelta

# %%
# Define ticker symbol
tickerSymbol = 'AAPL'

# %%
# Get the data on this ticker
Tickerdata =  yf.Ticker(tickerSymbol)

# %%
Tickerdata.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# get historical market data
hist = Tickerdata.history(period="1d", start="2010-1-1", end="2020-1-25")

# %%
hist
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2010-01-04 00:00:00-05:00   6.469951   6.502387   6.438122   6.487534
# 2010-01-05 00:00:00-05:00   6.505419   6.535430   6.464495   6.498750
# 2010-01-06 00:00:00-05:00   6.498750   6.524518   6.388710   6.395379
# 2010-01-07 00:00:00-05:00   6.419023   6.426602   6.337174   6.383555
# 2010-01-08 00:00:00-05:00   6.375068   6.426603   6.337479   6.425996
# ...                              ...        ...        ...        ...
# 2020-01-17 00:00:00-05:00  77.131574  77.733955  76.821851  77.731522
# 2020-01-21 00:00:00-05:00  77.355946  77.802241  77.065730  77.204742
# 2020-01-22 00:00:00-05:00  77.694946  78.038816  77.385223  77.480339
# 2020-01-23 00:00:00-05:00  77.533974  77.933931  76.980364  77.853455
# 2020-01-24 00:00:00-05:00  78.102200  78.853343  77.436408  77.629074
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# check last closing price
hist["Close"][-1]
# Out:
# 77.62907409667969

# %%
hist.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-01-04 00:00:00-05:00  6.469951  6.502387  6.438122  6.487534  493729600
# 2010-01-05 00:00:00-05:00  6.505419  6.535430  6.464495  6.498750  601904800
# 2010-01-06 00:00:00-05:00  6.498750  6.524518  6.388710  6.395379  552160000
# 2010-01-07 00:00:00-05:00  6.419023  6.426602  6.337174  6.383555  477131200
# 2010-01-08 00:00:00-05:00  6.375068  6.426603  6.337479  6.425996  447610800
#
#                            Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00        0.0           0.0
# 2010-01-05 00:00:00-05:00        0.0           0.0
# 2010-01-06 00:00:00-05:00        0.0           0.0
# 2010-01-07 00:00:00-05:00        0.0           0.0
# 2010-01-08 00:00:00-05:00        0.0           0.0

# %%
hist.shape
# Out:
# (2532, 7)

# %%
today = date.today()
today
# Out:
# datetime.date(2023, 10, 20)

# %%
d1 = today.strftime("%Y-%m-%d")
d1
# Out:
# '2023-10-20'

# %%
type(d1)
# Out:
# str

# %%
d2 = (today - timedelta(days=365)).strftime("%Y-%m-%d")
d2
# Out:
# '2022-10-20'

# %%
# Define the start and end dates
start_date = "2021-01-01"
end_date = "2021-12-31"

# Fetch stock data for TSLA (Tesla) in the specified date range
tsla = yf.Ticker("TSLA")
tsla_data = tsla.history(period='1d' ,start=start_date, end=end_date)

# %%
tsla_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  239.820007  248.163330  239.063339  243.256668
# 2021-01-05 00:00:00-05:00  241.220001  246.946671  239.733337  245.036667
# 2021-01-06 00:00:00-05:00  252.830002  258.000000  249.699997  251.993332
# 2021-01-07 00:00:00-05:00  259.209991  272.329987  258.399994  272.013336
# 2021-01-08 00:00:00-05:00  285.333344  294.829987  279.463318  293.339996
# ...                               ...         ...         ...         ...
# 2021-12-23 00:00:00-05:00  335.600006  357.660004  332.519989  355.666656
# 2021-12-27 00:00:00-05:00  357.890015  372.333344  356.906677  364.646667
# 2021-12-28 00:00:00-05:00  369.829987  373.000000  359.473328  362.823334
# 2021-12-29 00:00:00-05:00  366.213318  368.000000  354.713318  362.063324
# 2021-12-30 00:00:00-05:00  353.776672  365.183319  351.049988  356.779999
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
tsla_data.shape
# Out:
# (251, 7)

# %%
tsla_data.to_csv("Tsla_stock_market_data.csv")
